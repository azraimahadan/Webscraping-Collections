# %% [markdown]
# ## The Star News Article Scraping

# %% [markdown]
# ## Install and import required libraries

# %%
# !pip install newspaper3k
# !pip install autoscraper
#!pip install feedparser
# Out:
# Collecting newspaper3k
#   Downloading newspaper3k-0.2.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /opt/conda/lib/python3.10/site-packages (from newspaper3k) (4.12.2)
# Requirement already satisfied: Pillow>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from newspaper3k) (9.5.0)
# Requirement already satisfied: PyYAML>=3.11 in /opt/conda/lib/python3.10/site-packages (from newspaper3k) (6.0.1)
# Collecting cssselect>=0.9.2 (from newspaper3k)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: lxml>=3.6.0 in /opt/conda/lib/python3.10/site-packages (from newspaper3k) (5.1.0)
# Requirement already satisfied: nltk>=3.2.1 in /opt/conda/lib/python3.10/site-packages (from newspaper3k) (3.2.4)
# Requirement already satisfied: requests>=2.10.0 in /opt/conda/lib/python3.10/site-packages (from newspaper3k) (2.31.0)
# Collecting feedparser>=5.2.1 (from newspaper3k)
#   Downloading feedparser-6.0.11-py3-none-any.whl.metadata (2.4 kB)
# Collecting tldextract>=2.0.1 (from newspaper3k)
#   Downloading tldextract-5.1.2-py3-none-any.whl.metadata (11 kB)
# Collecting feedfinder2>=0.0.4 (from newspaper3k)
#   Downloading feedfinder2-0.0.4.tar.gz (3.3 kB)
# done
# Collecting jieba3k>=0.35.1 (from newspaper3k)
#   Downloading jieba3k-0.35.1.zip (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 67.0 MB/s eta 0:00:00
# done
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/conda/lib/python3.10/site-packages (from newspaper3k) (2.8.2)
# Collecting tinysegmenter==0.3 (from newspaper3k)
#   Downloading tinysegmenter-0.3.tar.gz (16 kB)
# done
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.5)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from feedfinder2>=0.0.4->newspaper3k) (1.16.0)
# Collecting sgmllib3k (from feedparser>=5.2.1->newspaper3k)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
# done
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.10.0->newspaper3k) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.10.0->newspaper3k) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.10.0->newspaper3k) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.10.0->newspaper3k) (2023.11.17)
# Collecting requests-file>=1.4 (from tldextract>=2.0.1->newspaper3k)
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /opt/conda/lib/python3.10/site-packages (from tldextract>=2.0.1->newspaper3k) (3.13.1)
# Downloading newspaper3k-0.2.8-py3-none-any.whl (211 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 11.8 MB/s eta 0:00:00
# Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Downloading feedparser-6.0.11-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 4.1 MB/s eta 0:00:00
# Downloading tldextract-5.1.2-py3-none-any.whl (97 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.6/97.6 kB 5.3 MB/s eta 0:00:00
# Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Building wheels for collected packages: tinysegmenter, feedfinder2, jieba3k, sgmllib3k
# done
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13538 sha256=a46ce87e4d5d8d9e5dfdcf9b823d2062ac4595282fc7992d5abbb91db27a23c0
#   Stored in directory: /root/.cache/pip/wheels/c8/d6/6c/384f58df48c00b9a31d638005143b5b3ac62c3d25fb1447f23
# done
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3340 sha256=22da33e27f69d91e2212b1e35a7b8093fcc54c89c519ed7275b09d4a543c302f
#   Stored in directory: /root/.cache/pip/wheels/97/02/e7/a1ff1760e12bdbaab0ac824fae5c1bc933e41c4ccd6a8f8edb
# done
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398381 sha256=37a98ea16cd870ba6a8941698d459f03f0cbd0b9794d23c61d35d0d469bbe368
#   Stored in directory: /root/.cache/pip/wheels/7a/c4/0c/12a9a314ecac499456c4c3b2fcc2f635a3b45a39dfbd240299
# done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6048 sha256=7b758338e55b6f880063e64191969806f94f1614714cb753ee6040e008c3e7ae
#   Stored in directory: /root/.cache/pip/wheels/f0/69/93/a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built tinysegmenter feedfinder2 jieba3k sgmllib3k
# Installing collected packages: tinysegmenter, sgmllib3k, jieba3k, feedparser, cssselect, requests-file, feedfinder2, tldextract, newspaper3k
# Successfully installed cssselect-1.2.0 feedfinder2-0.0.4 feedparser-6.0.11 jieba3k-0.35.1 newspaper3k-0.2.8 requests-file-2.1.0 sgmllib3k-1.0.0 tinysegmenter-0.3 tldextract-5.1.2
# Collecting autoscraper
#   Downloading autoscraper-1.1.14-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from autoscraper) (2.31.0)
# Collecting bs4 (from autoscraper)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from autoscraper) (5.1.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from bs4->autoscraper) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->autoscraper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->autoscraper) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->autoscraper) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->autoscraper) (2023.11.17)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->bs4->autoscraper) (2.5)
# Downloading autoscraper-1.1.14-py3-none-any.whl (10 kB)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4, autoscraper
# Successfully installed autoscraper-1.1.14 bs4-0.0.2

# %%
import pandas as pd
from autoscraper import AutoScraper
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ## Find the first link to be pass to Autoscraper

# %%
url_to_scrape="https://www.thestar.com.my/news/latest?tag=Nation"

response = requests.get(url_to_scrape)

soup = BeautifulSoup(response.text, 'html.parser')

# Find all <h2> tags with class "f18"
h2_tags = soup.find_all('h2', class_='f18')

for h2_tag in h2_tags:
    # Find the <a> tag within the <h2> tag
    a_tag = h2_tag.find('a')
    if a_tag:
        # Extract the link
        link = a_tag['href']
        
        break

# %%
link
# Out:
# 'https://www.thestar.com.my/news/nation/2024/05/23/malaysia-hong-kong-agree-to-collaborate-on-tvet-economy-says-zahid'

# %% [markdown]
# ## Find all the articles' link using Autoscraper

# %%
WantedLink=[link]

Scraper = AutoScraper()
url = Scraper.build(url_to_scrape, wanted_list=WantedLink)

# %%
# %%time

base_url = "https://www.thestar.com.my/news/latest?pgno={}&tag={}"
tags = ["Nation", "Business", "Education", "Aseanplus", "Sport", "Metro", "Tech", "World", "Lifestyle", "Food"]


all_news_urls = []

# Loop through each tag and page number
for tag in tags:
    for page_num in range(1, 11):  # Loop through 10 pages
        url_to_scrape = base_url.format(page_num, tag)
        
        # Get similar result for the current tag and page
        similar_results = Scraper.get_result_similar(url_to_scrape)
        
        all_news_urls.extend(similar_results)
# Out:
# CPU times: user 9.94 s, sys: 184 ms, total: 10.1 s
# Wall time: 2min 33s

# %%
all_news_urls[:10]
# Out:
# ['https://www.thestar.com.my/news/nation/2024/05/23/malaysia-hong-kong-agree-to-collaborate-on-tvet-economy-says-zahid',
#  'https://www.thestar.com.my/news/nation/2024/05/23/malaysia---china-relations-039special039-says-zahid-on-50th-diplomatic-anniversary',
#  'https://www.thestar.com.my/news/nation/2024/05/23/chinese-tourists-lead-international-visits-to-sabah-in-first-quarter-of-2024',
#  'https://www.thestar.com.my/news/nation/2024/05/23/three-nabbed-in-johor-for-stealing-cables',
#  'https://www.thestar.com.my/news/nation/2024/05/23/i-filed-police-report-to-stop-ebit-lew-says-witness',
#  'https://www.thestar.com.my/news/nation/2024/05/23/spm-2023-candidates-can-check-results-using-sms-education-ministry-website',
#  'https://www.thestar.com.my/news/nation/2024/05/23/cops-are-looking-for-missing-12-year-old-girl-in-muar',
#  'https://www.thestar.com.my/news/nation/2024/05/23/malaysia-to-leverage-asean-to-tackle-regional-issues-says-anwar',
#  'https://www.thestar.com.my/news/nation/2024/05/23/monorail-operator-gets-award-from-transport-minister-for-actions-during-kl-tree-collapse',
#  'https://www.thestar.com.my/news/nation/2024/05/23/1mdb-sues-psi-exec-uk-law-firm-for-rm861bil']

# %%
len(all_news_urls)
#paper.__dict__
# Out:
# 1644

# %% [markdown]
# ## Fetch articles' data using Newspaper3k

# %%
# %%time

import newspaper
from newspaper import Config

config = Config()
config.request_timeout = 30

article_details_list = []
# Loop through each URL
for url in all_news_urls:
    try:
        article = newspaper.Article(url=url, language='en', config=config)
        article.download()
        article.parse()

        meta_data = article.meta_data
        content_id = meta_data.get('content_id', None)
        section_name = meta_data.get('article_section_name', None)
        category = meta_data['cXenseParse'].get('kicker_name', None)
        tags = meta_data.get('content_tags', None)
        summary = meta_data.get('description', None)
        content_agency = meta_data.get('content_agency', None)
        content_tier =  meta_data.get('content_tier', None)
        content_length = meta_data.get('content_length', None)
        authors = meta_data.get('author', None)
        article_detail ={
            "content_id" : content_id,
            "title": str(article.title),
            "text": str(article.text),
            "section" : section_name,
            "category" :category,
            "content_tier":content_tier,
            "content_length":content_length,
            "authors": authors,
            "published_date": str(article.publish_date),
            #"videos": article.movies,
            "keywords": tags,
            "summary": summary,
            "url": url,
            "top_image": str(article.top_image),
        }
        
        article_details_list.append(article_detail)

    except newspaper.ArticleException as e:
        print(f"Failed to process URL: {url}. Error: {e}")

df_star = pd.DataFrame(article_details_list)
# Out:
# CPU times: user 4min 38s, sys: 2.83 s, total: 4min 41s
# Wall time: 45min 24s

# %%
df_star.head()
# Out:
#    content_id                                              title  \
# 0     1355430  Malaysia, Hong Kong agree to collaborate on TV...
# 1     1355429  Malaysia - China relations 'special', says Zah...
# 2     1355427  Chinese tourists lead international visits to ...
# 3     1355424          Three nabbed in Johor for stealing cables
# 1  2024-05-23 00:00:00  Ahmad Zahid,Malaysia,China,diplomatic ties,50 ...
# 2  2024-05-23 00:00:00  Sabah & Sarawak,Sabah tourism,Chinese visitors...
# 3  2024-05-23 00:00:00              Courts Crime,Cable,Theft,Police,Crime
# 4  2024-05-23 00:00:00  Magistrates Court,Tenom,Ebit Lew,sexual harass...
#
#                                              summary  \
# 0  HONG KONG: Malaysia and Hong Kong have agreed ...
# 1  HONG KONG: Datuk Seri Dr Ahmad Zahid Hamidi ha...
# 2  KOTA KINABALU: Sabah has proven to be a favori...
# 3  KULAI: Three men have been arrested for steali...
# 4  TENOM: The ninth witness in the sexual harassm...
#
#                                                  url  \
# 0  https://www.thestar.com.my/news/nation/2024/05...
# 1  https://www.thestar.com.my/news/nation/2024/05...
# 2  https://www.thestar.com.my/news/nation/2024/05...
# 3  https://www.thestar.com.my/news/nation/2024/05...
# 4  https://www.thestar.com.my/news/nation/2024/05...
#
#                                            top_image
# 0  https://apicms.thestar.com.my/uploads/images/2...
# 1  https://apicms.thestar.com.my/uploads/images/2...
# 2  https://apicms.thestar.com.my/uploads/images/2...
# 3  https://apicms.thestar.com.my/uploads/images/2...
# 4  https://apicms.thestar.com.my/uploads/images/2...

# %%
df_updated = df_updated.drop_duplicates(subset='content_id', keep='last')
df_updated
# Out:
#        content_id                                              title  \
# 3         1355424          Three nabbed in Johor for stealing cables
# 6         1355355  Cops are looking for missing 12-year-old girl ...
# 8         1355301  Monorail operator gets award from Transport Mi...
# 10        1355293  Police warn public not to share video of acid ...
# 11        1355291  Tun M says MACC has not asked him to declare a...
# ...           ...                                                ...
# 17753     1246234               Dazzling holiday feasts that delight
# 17754     1246232                 Wishing for a fairy-tale Christmas
# 17755     1246202  Get into the Christmas spirits: Gift ideas for...
# 17756     1245369                  Hearty meaty affair this Yuletide
# 17757     1245366  Year-end buffet that combines best of East and...
#
#                                                     text    section  \
# 3      KULAI: Three men have been arrested for steali...       News
# 6      MUAR: Police are looking for a 12-year-old gir...       News
# 8      KUALA LUMPUR: Monorail operator Ahmad Zahirudd...       News
# 10     PETALING JAYA: The police are warning the publ...       News
# 11     PETALING JAYA: Tun Dr Mahathir Mohamad says he...       News
# ...                                                  ...        ...
# 17753  A WONDERFUL time like Christmas calls for an e...       Food
# 17754  DESSERT for dinner? Why not, when a whimsical ...       Food
# 17755  There are only a few more sleeps left to Chris...  Lifestyle
# 17756  MANY have childhood memories that are rooted i...      Metro
# 17757  A ROAST prime rib can be an indulgent experien...      Metro
#
#          category   content_tier content_length         authors  \
# 3          Nation  Complimentary          Short            None
# 6          Nation  Complimentary          Short            None
# 8          Nation  Complimentary          Short            None
# 10         Nation  Complimentary          Short            None
# 11         Nation  Complimentary          Short            None
# ...           ...            ...            ...             ...
# 17753   Food News  Complimentary         Medium             NaN
# 17754   Food News  Complimentary         Medium             NaN
