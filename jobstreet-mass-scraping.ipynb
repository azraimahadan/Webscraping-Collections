# %% [markdown]
# # Import libraries

# %%
import pandas as pd
#from autoscraper import AutoScraper
from bs4 import BeautifulSoup
import requests
import numpy as np
import seaborn as sns
import re,random, time
from tqdm import tqdm

# %% [markdown]
# # WebScraping Code

# %%
def scrape_article_ids(api_url,max_pages):
    job_id =[]
    titles = []
    companies = []
    locations = []
    categorys= []
    subCategorys= []
    job_types=[]
    salarys=[]
    roles=[]
    listingDates = []

    for page_number in tqdm(range(1, max_pages + 1)):
        page_url = f'{api_url}&page={page_number}'
        
        # Send an HTTP request to the API endpoint
        response = requests.get(page_url)
        if response.status_code == 200:
            # Parse the JSON response
            data = response.json()

            # Extract advertiser IDs from each item in the 'data' list
            for item in data['data']:
                #print(item)
                jid = item['id']
                title = item['title']
                company = item['advertiser'].get('description', '')
                location = item.get('location', '')
                category = item['classification'].get('description', '')
                subCategory= item['subClassification'].get('description', '')
                job_type = item.get('workType', '')
                salary = item.get('salary', '')
                role = item.get('roleId','')
                listingDate = item.get('listingDate','')

                job_id.append(jid)
                titles.append(title)
                companies.append(company)
                locations.append(location)
                categorys.append(category)
                subCategorys.append(subCategory)
                job_types.append(job_type)
                salarys.append(salary)
                roles.append(role)
                listingDates.append(listingDate)
                #print(f"Job ID: {job_id}")

        else:
            print(f"Failed to retrieve data from the API. Status Code: {response.status_code}")


    return job_id, titles, companies, locations, categorys, subCategorys,job_types,salarys,roles,listingDates

# %%
def fetch_job_article(job_id):
    article_url = f'https://www.jobstreet.com.my/job/{job_id}'
    try:
        #response = requests.get(article_url, proxies={'https': proxy_url,'http':proxy_url})
        response = requests.get(article_url)
        if response.status_code == 200:
            return response.text
    except Exception as e:
        print(f"Error fetching {job_id}: {e}")
        return None

    print("Failed to retrieve job article using all proxies.")
    return None

def extract_text(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    div_tag = soup.find('div', class_='y735df0 _1pehz540')
    if div_tag:
        text = div_tag.get_text(strip=True, separator='\n')
        return text
    else:
        return "No description found"

def scrape_and_store_text(job_ids):
    data = {'job_id': [],'job_title':[],'company':[], 'descriptions': [], 'location':[],'category':[],'subcategory':[],'role':[],'type':[],'salary':[],'listingDate':[]}

    for job_id in tqdm(job_ids):
        job_article_content = fetch_job_article(job_id)
        
        delay = random.uniform(2, 7)
        time.sleep(delay)
        
        if job_article_content:
            descriptuion = extract_text(job_article_content)
            data['job_id'].append(job_id)
            data['descriptions'].append(descriptuion)
        else:
            data['job_id'].append(job_id)
            data['descriptions'].append("No description")            

    data['job_title'] = titles
    data['company'] = companies
    data['location'] = locations 
    data['category'] = categorys
    data['subcategory'] = subCategorys
    data['type']=job_types
    data['salary']=salarys
    data['role']=roles
    data['listingDate']=listingDates
    
    
    return data

# %%
# api url taken from Network -> Header 
api_url = 'https://www.jobstreet.com.my/api/chalice-search/v4/search?siteKey=MY-Main&sourcesystem=houston&userqueryid=d751713988987e9331980363e24189ce-6144301&userid=744fffcb-217e-4277-aafd-60aaceaac6f9&usersessionid=744fffcb-217e-4277-aafd-60aaceaac6f9&eventCaptureSessionId=744fffcb-217e-4277-aafd-60aaceaac6f9&seekSelectAllPages=true&pageSize=30&include=seodata&locale=en-MY&solId=568d2fe8-e8ef-4998-8e24-3e1ccfb1348b'
max_pages=100
job_id, titles, companies, locations, categorys, subCategorys,job_types,salarys,roles,listingDates = scrape_article_ids(api_url, max_pages)
# Out:
# 100%|██████████| 100/100 [00:45<00:00,  2.22it/s]

# %%
len(set(job_id))
# Out:
# 3200

# %%
a = 0
b=3000    #Limit to 3000 postings
job_id = job_id[a:b]
titles = titles[a:b]
companies = companies[a:b]
locations=locations[a:b]
categorys=categorys[a:b]
subCategorys=subCategorys[a:b]
job_types=job_types[a:b]
salarys=salarys[a:b]
roles=roles[a:b]
listingDates=listingDates[a:b]

# %%
len(set(job_id))
# Out:
# 3000

# %%
data = scrape_and_store_text(job_id)
# Out:
#  28%|██▊       | 847/3000 [1:13:12<3:32:55,  5.93s/it]
# Failed to retrieve job article using all proxies.
#  91%|█████████ | 2729/3000 [3:54:38<25:46,  5.71s/it]
# Failed to retrieve job article using all proxies.
# 100%|██████████| 3000/3000 [4:17:26<00:00,  5.15s/it]

# %%
new_df = pd.DataFrame(data)

# %%
new_df
# Out:
#         job_id                                          job_title  \
# 0     76145709                                  Account Executive
# 1     76146797          Associate Supervisor, Regulatory Practice
# 2     76146002                                    ADMIN ASSISTANT
# 3     76146806  Associate Supervisor, Surveillance and Enforce...
# 4     76127938        Assistant Manager, Marketing Communications
# ...        ...                                                ...
# 2995  75790244                             Industrial Engineer II
# 2996  75932952  Customer Service Coordinator (Vietnamese Speak...
# 2997  76111058             Content Creator Social Media Marketing
# 2998  75790426                          Sustainability Engineer I
# 2999  75787655                Technical Support Engineer(IT支援工程師)
#
#                                                 company  \
# 0                        Steel Hawk Engineering Sdn Bhd
# 1                                  Bank Negara Malaysia
# 2                          GRAND BULLION GOLD SDN. BHD.
# 3                                  Bank Negara Malaysia
# 4                                Boustead Ikano Sdn Bhd
# ...                                                 ...
# 2995                          Mattel (Malaysia) Sdn Bhd
# 2996  Hapag-Lloyd Business Services (Malaysia) Sdn. Bhd
# 2997                           Beeul Enterprise Sdn Bhd
# 2998                          Mattel (Malaysia) Sdn Bhd
# 2999                               Ark Tech (M) Sdn Bhd
#
#                                            descriptions              location  \
# 0     Key responsibilities:\nAble to handle full set...               Kemaman
# 1     ROLE PURPOSE:\nTo assess regulatory applicatio...          Kuala Lumpur
# 2     GB GOLD MALAYSIA\nWe are looking for a\nAdmin ...      Shah Alam/Subang
# 3     ROLE PURPOSE:\nTo conduct surveillance and tak...          Kuala Lumpur
# 4     PURPOSE OF THE JOB\nLead, mentor and develop a...          Kuala Lumpur
# ...                                                 ...                   ...
# 2995  Ensure compliance to QMS & EHS legal and other...        Seberang Perai
# 2996  Main Objectives of this position:\nProvides th...              Petaling
# 2997  🌟 Hey there, ready to join our team as a Socia...              Petaling
# 2998  This person has been assigned to assist the EH...        Seberang Perai
# 2999  Responsibilities:\nInvolve in new product intr...  Kajang/Bangi/Serdang
#
#                                     category  \
# 0                                 Accounting
# 1               Banking & Financial Services
# 2            Administration & Office Support
# 3               Banking & Financial Services
# 4                 Marketing & Communications
# ...                                      ...
# 2995                             Engineering
# 2996          Call Centre & Customer Service
# 2997              Marketing & Communications
# 2998                             Engineering
# 2999  Information & Communication Technology
#
#                                   subcategory                          role  \
# 0     Bookkeeping & Small Practice Accounting             account-executive
# 1                          Financial Planning                    supervisor
# 2                   Administrative Assistants        administration-officer
# 3                           Compliance & Risk                    supervisor
# 4                    Marketing Communications   assistant-marketing-manager
# ...                                       ...                           ...
# 2995                   Industrial Engineering           industrial-engineer
# 2996           Customer Service - Call Centre  customer-service-coordinator
# 2997               Digital & Search Marketing    marketing-and-social-media
# 2998        Electrical/Electronic Engineering       sustainability-engineer
# 2999                   Engineering - Hardware    technical-support-engineer
#
#            type                         salary           listingDate
# 0     Full time  RM 2,500 – RM 2,800 per month  2024-05-26T04:07:42Z
# 1     Full time                                 2024-05-26T08:44:41Z
# 2     Full time  RM 2,000 – RM 3,000 per month  2024-05-26T05:47:34Z
# 3     Full time                                 2024-05-26T08:49:24Z
# 4     Full time  RM 5,800 – RM 7,000 per month  2024-05-24T09:56:22Z
# ...         ...                            ...                   ...
# 2995  Full time  RM 5,000 – RM 6,500 per month  2024-05-13T02:14:42Z
# 2996  Full time                                 2024-05-16T10:56:20Z
# 2997  Full time  RM 2,800 – RM 4,000 per month  2024-05-24T05:14:10Z
# 2998  Full time  RM 3,400 – RM 5,100 per month  2024-05-13T02:20:01Z
# 2999  Full time  RM 2,800 – RM 4,000 per month  2024-05-13T00:55:04Z
#
# [3000 rows x 11 columns]

# %% [markdown]
# ## Load and Update Old dataset

# %%
df_prev = pd.read_csv("/kaggle/input/jobstreet-all-job-dataset/jobstreet_all_job_dataset.csv")
df_prev
# Out:
#          job_id                                          job_title  \
# 0      74630583                   Procurement Executive (Contract)
# 1      74660602                       Account Executive/ Assistant
# 2      74655679       Data Analyst - Asset Management, SPX Express
# 3      74657624                                   Service Engineer
# 4      74679363                               Purchasing Executive
# ...         ...                                                ...
# 48283  75947041                                        Staff Nurse
# 48284  75921336                                  Finance Executive
# 48285  75956420                        Assistant Quantity Surveyor
# 48286  75961993                         ISO Management System Lead
# 48287  75924824  Executive, Human Resources (Temporary July - O...
#
#                                       company  \
# 0       Coca-Cola Bottlers (Malaysia) Sdn Bhd
# 1          Acoustic & Lighting System Sdn Bhd
# 2              Shopee Mobile Malaysia Sdn Bhd
# 3                 Sun Medical Systems Sdn Bhd
# 4      Magnet Security & Automation Sdn. Bhd.
# ...                                       ...
# 48283                  Eternal Clinic Sdn Bhd
# 48284        Zeito Plastic Components Sdn Bhd
# 48285                       Inta Bina Sdn Bhd
# 48286            Faeth Asia Pacific Sdn. Bhd.
# 48287                Taylor's Education Group
#
#                                             descriptions         location  \
# 0      Position Purpose\nManage aspects of procuremen...  Negeri Sembilan
# 1      We are looking for a Account Executive/ Assist...         Petaling
# 2      Performs detailed data analysis on existing sp...   Klang District
# 3      You are important for troubleshooting, install...         Petaling
# 4      MAG is a trailblazer in the industry, boasting...      Hulu Langat
# ...                                                  ...              ...
# 48283  REQUIREMENTS:\n(Under K- Youth Programme, an i...         Selangor
# 48284  ZEITO PLASTIC COMPONENTS is a plastic componen...      Hulu Langat
# 48285  Job Responsibilities\nAssist Senior QS / CM in...         Petaling
# 48286  Job Descriptions\nMust be IRCA certified lead ...   Seberang Perai
# 48287  JOB PURPOSE\nThe Executive, Human Resources is...         Selangor
#
#                                    category  \
# 0      Manufacturing, Transport & Logistics
# 1                                Accounting
# 2      Manufacturing, Transport & Logistics
# 3                               Engineering
# 4      Manufacturing, Transport & Logistics
# ...                                     ...
# 48283                  Healthcare & Medical
# 48284  Manufacturing, Transport & Logistics
# 48285                          Construction
# 48286  Manufacturing, Transport & Logistics
# 48287         Human Resources & Recruitment
#
#                                    subcategory                         role  \
# 0          Purchasing, Procurement & Inventory        procurement-executive
# 1      Bookkeeping & Small Practice Accounting          executive-assistant
# 2                         Analysis & Reporting     asset-management-analyst
# 3            Electrical/Electronic Engineering            services-engineer
# 4          Purchasing, Procurement & Inventory         purchasing-executive
# ...                                        ...                          ...
# 48283     Nursing - General Medical & Surgical                  staff-nurse
# 48284                               Management            finance-executive
# 48285                                Surveying  assistant-quantity-surveyor
# 48286              Quality Assurance & Control                 systems-lead
# 48287               Consulting & Generalist HR     human-resource-executive
#
#                 type                         salary           listingDate
# 0      Contract/Temp                            NaN  2024-03-21T05:58:35Z
# 1          Full time  RM 2,800 – RM 3,200 per month  2024-03-22T06:52:57Z
# 2          Full time                            NaN  2024-03-22T04:22:43Z
# 3          Full time  RM 3,000 – RM 3,500 per month  2024-03-22T05:32:09Z
# 4          Full time  RM 2,800 – RM 3,500 per month  2024-03-23T03:56:39Z
# ...              ...                            ...                   ...
# 48283      Full time                            NaN  2024-05-17T02:40:43Z
# 48284      Full time  RM 3,500 – RM 3,800 per month  2024-05-16T04:35:28Z
# 48285      Full time                            NaN  2024-05-17T06:28:46Z
# 48286      Full time                            NaN  2024-05-17T09:11:05Z
# 48287  Contract/Temp              MYR 3,000 - 4,000  2024-05-16T06:23:28Z
#
# [48288 rows x 11 columns]

# %%
df_new = pd.concat([df_prev, new_df], ignore_index=True)
df_new
# Out:
#          job_id                                          job_title  \
# 0      74630583                   Procurement Executive (Contract)
# 1      74660602                       Account Executive/ Assistant
# 2      74655679       Data Analyst - Asset Management, SPX Express
# 3      74657624                                   Service Engineer
# 4      74679363                               Purchasing Executive
# ...         ...                                                ...
# 51283  75790244                             Industrial Engineer II
# 51284  75932952  Customer Service Coordinator (Vietnamese Speak...
# 51285  76111058             Content Creator Social Media Marketing
# 51286  75790426                          Sustainability Engineer I
# 51287  75787655                Technical Support Engineer(IT支援工程師)
#
#                                                  company  \
# 0                  Coca-Cola Bottlers (Malaysia) Sdn Bhd
# 1                     Acoustic & Lighting System Sdn Bhd
# 2                         Shopee Mobile Malaysia Sdn Bhd
# 3                            Sun Medical Systems Sdn Bhd
# 4                 Magnet Security & Automation Sdn. Bhd.
# ...                                                  ...
# 51283                          Mattel (Malaysia) Sdn Bhd
# 51284  Hapag-Lloyd Business Services (Malaysia) Sdn. Bhd
# 51285                           Beeul Enterprise Sdn Bhd
# 51286                          Mattel (Malaysia) Sdn Bhd
# 51287                               Ark Tech (M) Sdn Bhd
#
#                                             descriptions  \
# 0      Position Purpose\nManage aspects of procuremen...
# 1      We are looking for a Account Executive/ Assist...
# 2      Performs detailed data analysis on existing sp...
# 3      You are important for troubleshooting, install...
# 4      MAG is a trailblazer in the industry, boasting...
# ...                                                  ...
# 51283  Ensure compliance to QMS & EHS legal and other...
# 51284  Main Objectives of this position:\nProvides th...
# 51285  🌟 Hey there, ready to join our team as a Socia...
# 51286  This person has been assigned to assist the EH...
# 51287  Responsibilities:\nInvolve in new product intr...
#
#                    location                                category  \
# 0           Negeri Sembilan    Manufacturing, Transport & Logistics
# 1                  Petaling                              Accounting
# 2            Klang District    Manufacturing, Transport & Logistics
# 3                  Petaling                             Engineering
# 4               Hulu Langat    Manufacturing, Transport & Logistics
# ...                     ...                                     ...
# 51283        Seberang Perai                             Engineering
# 51284              Petaling          Call Centre & Customer Service
# 51285              Petaling              Marketing & Communications
# 51286        Seberang Perai                             Engineering
# 51287  Kajang/Bangi/Serdang  Information & Communication Technology
#
#                                    subcategory                          role  \
# 0          Purchasing, Procurement & Inventory         procurement-executive
# 1      Bookkeeping & Small Practice Accounting           executive-assistant
# 2                         Analysis & Reporting      asset-management-analyst
# 3            Electrical/Electronic Engineering             services-engineer
# 4          Purchasing, Procurement & Inventory          purchasing-executive
# ...                                        ...                           ...
# 51283                   Industrial Engineering           industrial-engineer
# 51284           Customer Service - Call Centre  customer-service-coordinator
# 51285               Digital & Search Marketing    marketing-and-social-media
# 51286        Electrical/Electronic Engineering       sustainability-engineer
# 51287                   Engineering - Hardware    technical-support-engineer
#
#                 type                         salary           listingDate
# 0      Contract/Temp                            NaN  2024-03-21T05:58:35Z
# 1          Full time  RM 2,800 – RM 3,200 per month  2024-03-22T06:52:57Z
# 2          Full time                            NaN  2024-03-22T04:22:43Z
# 3          Full time  RM 3,000 – RM 3,500 per month  2024-03-22T05:32:09Z
# 4          Full time  RM 2,800 – RM 3,500 per month  2024-03-23T03:56:39Z
# ...              ...                            ...                   ...
# 51283      Full time  RM 5,000 – RM 6,500 per month  2024-05-13T02:14:42Z
# 51284      Full time                                 2024-05-16T10:56:20Z
# 51285      Full time  RM 2,800 – RM 4,000 per month  2024-05-24T05:14:10Z
# 51286      Full time  RM 3,400 – RM 5,100 per month  2024-05-13T02:20:01Z
# 51287      Full time  RM 2,800 – RM 4,000 per month  2024-05-13T00:55:04Z
#
# [51288 rows x 11 columns]

# %%
df_new.drop_duplicates(subset=['job_id'],inplace=True)  # Drop any duplicated postings fom old dataset
len(df_new)
# Out:
# 50392

# %%
df_new = df_new[~(df_new['descriptions'].str.contains('No description'))]
len(df_new)
# Out:
# 50391

# %%
from datetime import datetime
current_date = datetime.now().strftime("%Y-%m-%d")

df_new.to_csv(f"jobstreet_all_job_dataset.csv",index=None)
